# %%
import numpy as np
import matplotlib.pyplot as plt
from os import listdir,walk
from os.path import isfile, join
from scipy.misc import imread
import math
import PIL

# %%
this=np.load('/Users/akaishuushan/Downloads/project/image_mean.npy')
this.shape
#this = np.reshape(this,(this.shape[1],this.shape[2],3))
# Out:
# (3, 256, 256)

# %%
h5f = h5py.File('img_mean.h5', 'w')
h5f.create_dataset('img_mean', data=this)
h5f.close()

# %%
plt.imshow(this)
plt.savefig( 'mean.png' ) 
plt.show()

# %%
this.min()

# %%
this.dtype

# %%
this= this.astype('uint8')

# %%
plt.imshow(this)
plt.show()
